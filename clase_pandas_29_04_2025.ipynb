# %% [markdown]
# # Demostrar que el método de Ruffini puede ser usado para evaluar un polinomio en $𝑥 = 𝑎$. Demuestre además, cómo a partir de dicho método se puede deducir otro, el método de Horner para evaluar polinomios.
#
# # javierpedro.garcia@unahur.edu.ar

# %%
from math import *
import numpy as np
import pandas as pd


def g(x):
    return cos(x)


def punto_fijo(g, n , x):
    i = 1
    while i < n:
        x = g(x)
        i = i+1
    return x


sucesion = np.array([punto_fijo(g, n, 1) for n in range(1, 50)])

#indice = range(1, 10)

#mi_dataframe = pd.DataFrame(sucesion, columns=[ 'xn'])

mi_dataframe = pd.DataFrame(sucesion, columns=[ 'xn'], index=range(1, 50))



mi_dataframe
# Out:
#           xn
# 1   1.000000
# 2   0.540302
# 3   0.857553
# 4   0.654290
# 5   0.793480
# 6   0.701369
# 7   0.763960
# 8   0.722102
# 9   0.750418
# 10  0.731404
# 11  0.744237
# 12  0.735605
# 13  0.741425
# 14  0.737507
# 15  0.740147
# 16  0.738369
# 17  0.739567
# 18  0.738760
# 19  0.739304
# 20  0.738938
# 21  0.739184
# 22  0.739018
# 23  0.739130
# 24  0.739055
# 25  0.739106
# 26  0.739071
# 27  0.739094
# 28  0.739079
# 29  0.739089
# 30  0.739082
# 31  0.739087
# 32  0.739084
# 33  0.739086
# 34  0.739085
# 35  0.739086
# 36  0.739085
# 37  0.739085
# 38  0.739085
# 39  0.739085
# 40  0.739085
# 41  0.739085
# 42  0.739085
# 43  0.739085
# 44  0.739085
# 45  0.739085
# 46  0.739085
# 47  0.739085
# 48  0.739085
# 49  0.739085

# %%
mi_dataframe['shift'] = mi_dataframe['xn'].shift(-1)

mi_dataframe
# Out:
#           xn     shift
# 1   1.000000  0.540302
# 2   0.540302  0.857553
# 3   0.857553  0.654290
# 4   0.654290  0.793480
# 5   0.793480  0.701369
# 6   0.701369  0.763960
# 7   0.763960  0.722102
# 8   0.722102  0.750418
# 9   0.750418  0.731404
# 10  0.731404  0.744237
# 11  0.744237  0.735605
# 12  0.735605  0.741425
# 13  0.741425  0.737507
# 14  0.737507  0.740147
# 15  0.740147  0.738369
# 16  0.738369  0.739567
# 17  0.739567  0.738760
# 18  0.738760  0.739304
# 19  0.739304  0.738938
# 20  0.738938  0.739184
# 21  0.739184  0.739018
# 22  0.739018  0.739130
# 23  0.739130  0.739055
# 24  0.739055  0.739106
# 25  0.739106  0.739071
# 26  0.739071  0.739094
# 27  0.739094  0.739079
# 28  0.739079  0.739089
# 29  0.739089  0.739082
# 30  0.739082  0.739087
# 31  0.739087  0.739084
# 32  0.739084  0.739086
# 33  0.739086  0.739085
# 34  0.739085  0.739086
# 35  0.739086  0.739085
# 36  0.739085  0.739085
# 37  0.739085  0.739085
# 38  0.739085  0.739085
# 39  0.739085  0.739085
# ...

# %%
mi_dataframe['cociente'] = mi_dataframe['shift']/mi_dataframe['xn']

mi_dataframe
# Out:
#           xn     shift  cociente
# 1   1.000000  0.540302  0.540302
# 2   0.540302  0.857553  1.587173
# 3   0.857553  0.654290  0.762973
# 4   0.654290  0.793480  1.212735
# 5   0.793480  0.701369  0.883914
# 6   0.701369  0.763960  1.089241
# 7   0.763960  0.722102  0.945210
# 8   0.722102  0.750418  1.039212
# 9   0.750418  0.731404  0.974662
# 10  0.731404  0.744237  1.017546
# 11  0.744237  0.735605  0.988401
# 12  0.735605  0.741425  1.007912
# 13  0.741425  0.737507  0.994715
# 14  0.737507  0.740147  1.003580
# 15  0.740147  0.738369  0.997598
# 16  0.738369  0.739567  1.001622
# 17  0.739567  0.738760  0.998909
# 18  0.738760  0.739304  1.000736
# 19  0.739304  0.738938  0.999505
# 20  0.738938  0.739184  1.000334
# 21  0.739184  0.739018  0.999775
# 22  0.739018  0.739130  1.000151
# 23  0.739130  0.739055  0.999898
# 24  0.739055  0.739106  1.000069
# 25  0.739106  0.739071  0.999954
# 26  0.739071  0.739094  1.000031
# 27  0.739094  0.739079  0.999979
# ...

# %%
mi_dataframe = mi_dataframe.drop(columns=['shift'])

mi_dataframe
# Out:
#           xn  cociente
# 1   1.000000  0.540302
# 2   0.540302  1.587173
# 3   0.857553  0.762973
# 4   0.654290  1.212735
# 5   0.793480  0.883914
# 6   0.701369  1.089241
# 7   0.763960  0.945210
# 8   0.722102  1.039212
# 9   0.750418  0.974662
# 10  0.731404  1.017546
# 11  0.744237  0.988401
# 12  0.735605  1.007912
# 13  0.741425  0.994715
# 14  0.737507  1.003580
# 15  0.740147  0.997598
# 16  0.738369  1.001622
# 17  0.739567  0.998909
# 18  0.738760  1.000736
# 19  0.739304  0.999505
# 20  0.738938  1.000334
# 21  0.739184  0.999775
# 22  0.739018  1.000151
# 23  0.739130  0.999898
# 24  0.739055  1.000069
# 25  0.739106  0.999954
# 26  0.739071  1.000031
# 27  0.739094  0.999979
# 28  0.739079  1.000014
# 29  0.739089  0.999990
# 30  0.739082  1.000006
# 31  0.739087  0.999996
# 32  0.739084  1.000003
# 33  0.739086  0.999998
# 34  0.739085  1.000001
# 35  0.739086  0.999999
# 36  0.739085  1.000001
# 37  0.739085  1.000000
# 38  0.739085  1.000000
# 39  0.739085  1.000000
# ...
